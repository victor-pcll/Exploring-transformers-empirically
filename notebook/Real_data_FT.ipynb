# %% [markdown]
# # Realistic dataset

# %%
import pandas as pd
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import glob
import os

# %%
# --- 1. Global Academic Style Configuration ---
plt.rcParams.update({
    'font.family': 'serif',
    'font.serif': ['Times New Roman', 'DejaVu Serif'],
    'mathtext.fontset': 'cm',
    'axes.labelsize': 16,
    'axes.titlesize': 16,
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'legend.fontsize': 13,
    'axes.grid': True,
    'grid.alpha': 0.3,
    'grid.linestyle': '--',
    'lines.linewidth': 2,
    'lines.markersize': 6,
    'figure.dpi': 300,
    'savefig.bbox': 'tight',
})

# %%
plot_path = f"../results/Realistic_dataset"
os.makedirs(plot_path, exist_ok=True)

# %% [markdown]
# ## Label error + ACC vs. alpha (d_MLP fix)

# %%
# 100 + Fine-Tune
run_id_S = "20251229_2236"
run_id_tied = "20251229_1253"
run_id_untied = "20251230_1021" # mlp = 50 et 0.2
run_id_S_sym = "20251217_2250"

run_dir_S = f"../results/run_{run_id_S}/"
config_path_S = f"../results/run_{run_id_S}/config.csv"
base_path_S = f"../results/run_{run_id_S}/summary.csv"

run_dir_tied = f"../results/run_{run_id_tied}/"
config_path_tied = f"../results/run_{run_id_tied}/config.csv"
base_path_tied = f"../results/run_{run_id_tied}/summary.csv"

run_dir_untied = f"../results/run_{run_id_untied}/"
config_path_untied = f"../results/run_{run_id_untied}/config.csv"
base_path_untied = f"../results/run_{run_id_untied}/summary.csv"

run_dir_S_sym = f"../results/run_{run_id_S_sym}/"
config_path_S_sym = f"../results/run_{run_id_S_sym}/config.csv"
base_path_S_sym = f"../results/run_{run_id_S_sym}/summary.csv"

# --- Unfactorized ---
df_S = pd.read_csv(base_path_S)
print(f"✅ Summary loaded ({len(df_S)} rows) from {base_path_S}")
display(df_S.head())

df_S_sym = pd.read_csv(base_path_S_sym)
print(f"✅ Summary loaded ({len(df_S_sym)} rows) from {base_path_S_sym}")
display(df_S_sym.head())

# --- Tied ---
df_tied = pd.read_csv(base_path_tied)
print(f"✅ Summary loaded ({len(df_tied)} rows) from {base_path_tied}")
display(df_tied.head())

# --- Untied ---
df_untied = pd.read_csv(base_path_untied)
print(f"✅ Summary loaded ({len(df_untied)} rows) from {base_path_untied}")
display(df_untied.head())
plt.rcParams.update({'font.size': 12}) 

plt.rcParams.update({'font.size': 12})
# Out:
# ✅ Summary loaded (15 rows) from ../results/run_20251229_2236/summary.csv
#       alpha  MLP_dim  rho  p_ft    lamda  label_err_mean  label_err_std  \
# 0  0.010000      100  1.0   0.1  0.00010        0.808777       0.007637
# 1  0.151429      100  1.0   0.1  0.00010        0.495027       0.080811
# 2  0.222143      100  1.0   0.1  0.00001        0.478410       0.088826
# 3  0.080714      100  1.0   0.1  0.00010        0.597492       0.059388
# 4  0.646429      100  1.0   0.1  0.00010        0.457603       0.049374
#
#    train_data_mean  train_reg_mean  train_total_mean  ...  acc_test_mean  \
# 0         0.000028        0.000023          0.000051  ...       0.191223
# 1         0.000125        0.000023          0.000148  ...       0.504973
# 2         0.000118        0.000007          0.000125  ...       0.521590
# 3         0.000099        0.000027          0.000126  ...       0.402508
# 4         0.000122        0.000022          0.000144  ...       0.542397
#
#    acc_test_std  acc_fine_tune_mean  acc_fine_tune_std  acc_train_mean  \
# 0      0.007637            0.713756           0.087397        0.908128
# 1      0.080811            0.555902           0.081067        0.536430
# 2      0.088826            0.550314           0.078853        0.551915
# 3      0.059388            0.499593           0.053433        0.627966
# 4      0.049374            0.532189           0.063223        0.542171
#
#    acc_train_std  rank_before_mean  rank_before_std  rank_after_mean  \
# 0       0.123297              98.7         2.540779             99.5
# 1       0.101159              98.2         1.135292             99.3
# 2       0.111887              99.6         0.516398             94.2
# 3       0.065141              97.1         4.012481             99.1
# 4       0.056566              96.6         5.037636             98.8
#
#    rank_after_std
# 0        0.707107
# 1        0.674949
# 2        4.613988
# 3        0.567646
# 4        0.632456
#
# [5 rows x 21 columns]
# ✅ Summary loaded (15 rows) from ../results/run_20251217_2250/summary.csv
#       alpha  MLP_dim  rho  p_ft    lamda  label_err_mean  label_err_std  \
# 0  0.010000      100  1.0   0.0  0.00100        0.774327       0.018129
# 1  0.080714      100  1.0   0.0  0.00001        0.597375       0.109158
# 2  0.151429      100  1.0   0.0  0.00010        0.555030       0.045209
# 3  0.222143      100  1.0   0.0  0.00010        0.517062       0.065567
# 4  0.292857      100  1.0   0.0  0.00010        0.512725       0.107684
#
#    train_data_mean  train_reg_mean  train_total_mean  ...  acc_test_mean  \
# 0         0.000087        0.000072          0.000160  ...       0.225673
# 1         0.000131        0.000008          0.000139  ...       0.402625
# 2         0.000133        0.000019          0.000153  ...       0.444970
# 3         0.000138        0.000020          0.000158  ...       0.482938
# 4         0.000136        0.000020          0.000155  ...       0.487275
#
#    acc_test_std  acc_fine_tune_mean  acc_fine_tune_std  acc_train_mean  \
# 0      0.018129                 NaN                NaN        0.730721
# 1      0.109158                 NaN                NaN        0.513797
# 2      0.045209                 NaN                NaN        0.503174
# 3      0.065567                 NaN                NaN        0.493935
# 4      0.107684                 NaN                NaN        0.496163
#
#    acc_train_std  rank_before_mean  rank_before_std  rank_after_mean  \
# 0       0.071594              96.8         1.135292             96.8
# 1       0.150480              95.1         0.994429             95.1
# 2       0.058223              98.0         0.816497             98.0
# 3       0.057325              97.8         1.398412             97.8
# 4       0.129127              97.2         1.813529             97.2
#
#    rank_after_std
# 0        1.135292
# 1        0.994429
# 2        0.816497
# 3        1.398412
# 4        1.813529
#
# [5 rows x 21 columns]
# ✅ Summary loaded (14 rows) from ../results/run_20251229_1253/summary.csv
#       alpha  MLP_dim  rho  p_ft    lamda  label_err_mean  label_err_std  \
# 0  0.010000      100  1.0   0.1  0.00001        0.745952       0.016760
# 1  0.080714      100  1.0   0.1  0.00001        0.246227       0.039177
# 2  0.151429      100  1.0   0.1  0.00001        0.163200       0.035579
# 3  0.222143      100  1.0   0.1  0.00001        0.122360       0.040739
# 4  0.575714      100  1.0   0.1  0.00001        0.105728       0.039827
#
#    train_data_mean  train_reg_mean  train_total_mean  ...  acc_test_mean  \
# 0         0.000016        0.000008          0.000024  ...       0.254048
# 1         0.000038        0.000010          0.000048  ...       0.753773
# 2         0.000038        0.000012          0.000050  ...       0.836800
# 3         0.000034        0.000014          0.000048  ...       0.877640
# 4         0.000034        0.000015          0.000048  ...       0.894272
#
#    acc_test_std  acc_fine_tune_mean  acc_fine_tune_std  acc_train_mean  \
# 0      0.016760            0.585164           0.081342        0.940453
# 1      0.039177            0.785142           0.045517        0.862147
# 2      0.035579            0.879845           0.036618        0.854359
# 3      0.040739            0.874881           0.042843        0.882841
# 4      0.039827            0.907043           0.029230        0.880256
#
#    acc_train_std  rank_before_mean  rank_before_std  rank_after_mean  \
# 0       0.067577             100.0         0.000000             99.7
# 1       0.044769              98.1         2.601282             98.6
# 2       0.044856              95.8         6.338594             97.5
# 3       0.051388              94.3         4.967673             93.0
# 4       0.045956              85.8        12.673682             93.9
#
#    rank_after_std
# 0        0.483046
# 1        2.319004
# 2        3.922867
# 3        7.586538
# 4        6.690790
#
# [5 rows x 21 columns]
# ✅ Summary loaded (2 rows) from ../results/run_20251230_1021/summary.csv
#       alpha  MLP_dim  rho  p_ft    lamda  label_err_mean  label_err_std  \
# 0  0.010000       50  1.0   0.2  0.00001        0.812177       0.006794
# 1  0.222143       50  1.0   0.2  0.00010        0.350543       0.064472
#
#    train_data_mean  train_reg_mean  train_total_mean  ...  acc_train_mean  \
# 0         0.000031        0.000015          0.000047  ...        0.868354
# 1         0.000095        0.000039          0.000134  ...        0.664408
#
#    acc_train_std  rank_Q_before_mean  rank_Q_before_std  rank_K_before_mean  \
# 0       0.133654               100.0           0.000000               100.0
# 1       0.061959                75.2          11.573917                75.1
#
#    rank_K_before_std  rank_Q_after_mean  rank_Q_after_std  rank_K_after_mean  \
# 0           0.000000              100.0          0.000000              100.0
# 1          10.764654               85.2          7.495184               85.1
#
#    rank_K_after_std
# 0          0.000000
# 1          6.556591
#
# [2 rows x 25 columns]

# %%
# --- 2. Préparation des données ---
MLP_target = 50  # <-- Choisis ton d_MLP

# Vérification et filtrage pour les 3 DataFrames
if 'df_S' in locals() and 'df_tied' in locals() and 'df_untied' in locals():
    subset_S = df_S[df_S["MLP_dim"] == MLP_target].sort_values("alpha")
    subset_tied = df_tied[df_tied["MLP_dim"] == MLP_target].sort_values("alpha")
    subset_untied = df_untied[df_untied["MLP_dim"] == MLP_target].sort_values("alpha")
    subset_S_sym = df_S_sym[df_S_sym["MLP_dim"] == MLP_target].sort_values("alpha")
else:
    print("⚠️ DataFrames 'df_S', 'df_tied' or 'df_untied' not found.")
    subset_S, subset_tied, subset_untied, subset_S_sym  = pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame()

def plot_compare_vs_alpha(
    data_s, data_tied, data_untied, data_S_sym,
    y_col, y_err_col, 
    ylabel, filename, 
    loc_legend='best'
):
    fig, ax = plt.subplots(figsize=(8, 5)) # Un peu plus large pour la légende

    # --- CONFIGURATION DES STYLES ---
    # On définit des styles contrastés pour chaque catégorie
    styles = [
        # Label, Color, Marker, LineStyle
        ("Unfactorized", "#E69F00", "o", "-"),       # Orange, Cercle, Plein
        ("Symmetric Unfactorized", "#CC79A7", "D", "--"), # Rose/Mauve, Diamant, Tirets
        ("Factorized (Tied)", "#0072B2", "s", "-."),  # Bleu, Carré, Mixte
        ("Untied", "#009E73", "^", ":"), # Vert, Triangle, Pointillés
    ]
    
    datasets = [data_s, data_S_sym, data_tied, data_untied]

    for data, (label, color, marker, ls) in zip(datasets, styles):
        if not data.empty:
            ax.errorbar(
                data["alpha"],
                data[y_col],
                yerr=data.get(y_err_col, 0),
                label=label,
                color=color,
                marker=marker,
                linestyle=ls,
                markersize=6,      # Marqueurs légèrement plus grands
                linewidth=1.8,     # Ligne un peu plus épaisse
                capsize=3,         # Petites barres au bout des erreurs
                elinewidth=1,
                alpha=0.9
            )

    # --- Labels et Style ---
    ax.set_xlabel(r"Sample Complexity $\alpha = n/d^2$", fontsize=16)
    ax.set_ylabel(ylabel, fontsize=16)
    
    # Grille légère pour la lecture des valeurs
    ax.grid(True, linestyle='--', alpha=0.4)

    # --- STYLE BOÎTE ---
    ax.set_axisbelow(True)
    ax.tick_params(direction='in', top=True, right=True, which='both')
    
    for spine in ax.spines.values():
        spine.set_linewidth(1.0)

    # Légende optimisée
    ax.legend(frameon=True, fontsize=12, edgecolor='black', framealpha=1.0, loc=loc_legend)
    
    plt.tight_layout()
    
    # Sauvegarde
    if not os.path.exists(plot_path): os.makedirs(plot_path)
    save_full = os.path.join(plot_path, filename)
    plt.savefig(save_full, dpi=300, bbox_inches='tight')
    print(f"✅ Saved plot: {save_full}")
    plt.show()

# --- 4. Exécution ---

if not subset_S.empty and not subset_tied.empty and not subset_untied.empty:
    
    # Récupération d'un ID de run pour le nom de fichier (optionnel)
    run_suffix = f"_run{run_id_S}" if 'run_id_S' in locals() else ""

    # -------------------- LABEL ERROR --------------------
    plot_compare_vs_alpha(
        subset_S, subset_tied, subset_untied, subset_S_sym,
        y_col="label_err_mean",
        y_err_col="label_err_std",
        ylabel="Test Error",
        filename=f"label_error_vs_alpha_MLP{MLP_target}{run_suffix}.png",
        loc_legend="upper right" 
    )

    # -------------------- TEST ACCURACY --------------------
    plot_compare_vs_alpha(
        subset_S, subset_tied, subset_untied, subset_S_sym,
        y_col="acc_test_mean",
        y_err_col="acc_test_std",
        ylabel="Test Accuracy",
        filename=f"test_accuracy_vs_alpha_MLP{MLP_target}{run_suffix}.png",
        loc_legend="lower right"
    )

else:
    print(f"⚠️ One of the subsets is empty for MLP_dim = {MLP_target}")
# Out:
# ⚠️ One of the subsets is empty for MLP_dim = 50

# %% [markdown]
# # Analysis for S and constraints

# %%
# --- 1. Configuration des Run IDs ---
# Remplace les IDs ci-dessous par les tiens
run_id_S = "20251217_1517"          # S (Standard)
run_id_S_sym = "20251217_2250"      # S Symmetric
run_id_S_sym_141 = "20251218_1637"  # S Symétrie (d=141) -> À REMPLACER

# --- 2. Définition des Chemins (Paths) ---

# S
run_dir_S = f"../results/run_{run_id_S}/"
base_path_S = f"../results/run_{run_id_S}/summary.csv"

# S Symmetric
run_dir_S_sym = f"../results/run_{run_id_S_sym}/"
base_path_S_sym = f"../results/run_{run_id_S_sym}/summary.csv"

# S Symétrie (d=141)
run_dir_S_sym_141 = f"../results/run_{run_id_S_sym_141}/"
base_path_S_sym_141 = f"../results/run_{run_id_S_sym_141}/summary.csv"

# --- 3. Chargement des Données (Data Loading) ---

# --- S ---
df_S = pd.read_csv(base_path_S)
print(f"✅ S: Summary loaded ({len(df_S)} rows) from {base_path_S}")
display(df_S.head())

# --- S Symmetric ---
df_S_sym = pd.read_csv(base_path_S_sym)
print(f"✅ S Symmetric: Summary loaded ({len(df_S_sym)} rows) from {base_path_S_sym}")
display(df_S_sym.head())

# --- S Symétrie (d=141) ---
df_S_sym_141 = pd.read_csv(base_path_S_sym_141)
print(f"✅ S Sym (d=141): Summary loaded ({len(df_S_sym_141)} rows) from {base_path_S_sym_141}")
display(df_S_sym_141.head())

# Configuration globale pour les plots
plt.rcParams.update({'font.size': 12})
# Out:
# ✅ S: Summary loaded (15 rows) from ../results/run_20251217_1517/summary.csv
#       alpha  MLP_dim  rho  p_ft    lamda  label_err_mean  label_err_std  \
# 0  0.010000      100  1.0   0.0  0.00010        0.784717       0.020970
# 1  0.151429      100  1.0   0.0  0.00010        0.515765       0.049527
# 2  0.080714      100  1.0   0.0  0.00010        0.539913       0.095058
# 3  0.222143      100  1.0   0.0  0.00001        0.442643       0.066018
# 4  0.434286      100  1.0   0.0  0.00010        0.430325       0.070167
#
#    train_data_mean  train_reg_mean  train_total_mean  ...  acc_test_mean  \
# 0         0.000047        0.000023          0.000070  ...       0.215283
# 1         0.000125        0.000020          0.000145  ...       0.484235
# 2         0.000112        0.000024          0.000136  ...       0.460087
# 3         0.000105        0.000009          0.000113  ...       0.557357
# 4         0.000113        0.000024          0.000137  ...       0.569675
#
#    acc_test_std  acc_fine_tune_mean  acc_fine_tune_std  acc_train_mean  \
# 0      0.020970                 NaN                NaN        0.825830
# 1      0.049527                 NaN                NaN        0.531923
# 2      0.095058                 NaN                NaN        0.565409
# 3      0.066018                 NaN                NaN        0.605441
# 4      0.070167                 NaN                NaN        0.579738
#
#    acc_train_std  rank_before_mean  rank_before_std  rank_after_mean  \
# 0       0.217864             100.0         0.000000            100.0
# 1       0.051794              98.5         0.707107             98.5
# 2       0.136588              98.8         1.398412             98.8
# 3       0.068364              99.5         0.527046             99.5
# 4       0.067375              97.9         1.595131             97.9
#
#    rank_after_std
# 0        0.000000
# 1        0.707107
# 2        1.398412
# 3        0.527046
# 4        1.595131
#
# [5 rows x 21 columns]
# ✅ S Symmetric: Summary loaded (15 rows) from ../results/run_20251217_2250/summary.csv
#       alpha  MLP_dim  rho  p_ft    lamda  label_err_mean  label_err_std  \
# 0  0.010000      100  1.0   0.0  0.00100        0.774327       0.018129
# 1  0.080714      100  1.0   0.0  0.00001        0.597375       0.109158
# 2  0.151429      100  1.0   0.0  0.00010        0.555030       0.045209
# 3  0.222143      100  1.0   0.0  0.00010        0.517062       0.065567
# 4  0.292857      100  1.0   0.0  0.00010        0.512725       0.107684
#
#    train_data_mean  train_reg_mean  train_total_mean  ...  acc_test_mean  \
# 0         0.000087        0.000072          0.000160  ...       0.225673
# 1         0.000131        0.000008          0.000139  ...       0.402625
# 2         0.000133        0.000019          0.000153  ...       0.444970
# 3         0.000138        0.000020          0.000158  ...       0.482938
# 4         0.000136        0.000020          0.000155  ...       0.487275
#
#    acc_test_std  acc_fine_tune_mean  acc_fine_tune_std  acc_train_mean  \
# 0      0.018129                 NaN                NaN        0.730721
# 1      0.109158                 NaN                NaN        0.513797
# 2      0.045209                 NaN                NaN        0.503174
# 3      0.065567                 NaN                NaN        0.493935
# 4      0.107684                 NaN                NaN        0.496163
#
#    acc_train_std  rank_before_mean  rank_before_std  rank_after_mean  \
# 0       0.071594              96.8         1.135292             96.8
# 1       0.150480              95.1         0.994429             95.1
# 2       0.058223              98.0         0.816497             98.0
# 3       0.057325              97.8         1.398412             97.8
# 4       0.129127              97.2         1.813529             97.2
#
#    rank_after_std
# 0        1.135292
# 1        0.994429
# 2        0.816497
# 3        1.398412
# 4        1.813529
#
# [5 rows x 21 columns]
# ✅ S Sym (d=141): Summary loaded (15 rows) from ../results/run_20251218_1637/summary.csv
#       alpha  MLP_dim  rho  p_ft   lamda  label_err_mean  label_err_std  \
# 0  0.010000      100  1.0   0.0  0.0010        0.753478       0.020830
# 1  0.080714      100  1.0   0.0  0.0001        0.541565       0.081382
# 2  0.222143      100  1.0   0.0  0.0001        0.517667       0.028297
# 3  0.505000      100  1.0   0.0  0.0001        0.496615       0.051742
# 4  0.151429      100  1.0   0.0  0.0001        0.516383       0.056144
#
#    train_data_mean  train_reg_mean  train_total_mean  ...  acc_test_mean  \
# 0         0.000082        0.000025          0.000107  ...       0.246522
# 1         0.000070        0.000010          0.000080  ...       0.458435
# 2         0.000068        0.000010          0.000078  ...       0.482333
# 3         0.000068        0.000010          0.000078  ...       0.503385
# 4         0.000066        0.000011          0.000077  ...       0.483617
#
#    acc_test_std  acc_fine_tune_mean  acc_fine_tune_std  acc_train_mean  \
# 0      0.020830                 NaN                NaN        0.424288
# 1      0.081382                 NaN                NaN        0.491223
# 2      0.028297                 NaN                NaN        0.498369
# 3      0.051742                 NaN                NaN        0.501507
# 4      0.056144                 NaN                NaN        0.512727
#
#    acc_train_std  rank_before_mean  rank_before_std  rank_after_mean  \
# 0       0.087007             132.2         5.940445            132.2
# 1       0.097627             136.8         2.394438            136.8
# 2       0.030062             137.2         2.740641            137.2
# 3       0.049363             137.9         1.449138            137.9
# 4       0.054659             137.0         1.943651            137.0
#
#    rank_after_std
# 0        5.940445
# 1        2.394438
# 2        2.740641
# 3        1.449138
# 4        1.943651
#
# [5 rows x 21 columns]

# %%
# --- 2. Préparation des données ---
MLP_target = 100  # <-- Choisis ton d_MLP

# Liste des dataframes attendus
required_dfs = ['df_S', 'df_S_sym', 'df_S_sym_141']
missing_dfs = [name for name in required_dfs if name not in locals()]

if not missing_dfs:
    # Filtrage par MLP_dim et tri par alpha
    subset_S = df_S[df_S["MLP_dim"] == MLP_target].sort_values("alpha")
    subset_S_sym = df_S_sym[df_S_sym["MLP_dim"] == MLP_target].sort_values("alpha")
    subset_S_sym_141 = df_S_sym_141[df_S_sym_141["MLP_dim"] == MLP_target].sort_values("alpha")
else:
    print(f"⚠️ Missing DataFrames: {missing_dfs}")
    subset_S, subset_S_sym, subset_S_sym_141 = [pd.DataFrame()] * 3

def plot_compare_vs_alpha(
    data_S, data_S_sym, data_S_sym_141, 
    y_col, y_err_col, 
    ylabel, filename, 
    loc_legend='best'
):
    fig, ax = plt.subplots(figsize=(8, 5)) 

    # --- CONFIGURATION DES STYLES ---
    styles = [
        # Label, Color, Marker, LineStyle
        ("S",                        "#E69F00", "o", "-"),   # Orange, Cercle
        ("S Symmetric",              "#CC79A7", "D", "--"),  # Rose/Mauve, Diamant
        (r"S Symétrie ($d=141$)",    "#0072B2", "s", "-."),  # Bleu, Carré
    ]
    
    # Ordre des données correspondant aux styles ci-dessus
    datasets = [data_S, data_S_sym, data_S_sym_141]

    for data, (label, color, marker, ls) in zip(datasets, styles):
        if not data.empty:
            ax.errorbar(
                data["alpha"],
                data[y_col],
                yerr=data.get(y_err_col, 0),
                label=label,
                color=color,
                marker=marker,
                linestyle=ls,
                markersize=6,
                linewidth=1.8,
                capsize=3,
                elinewidth=1,
                alpha=0.9
            )

    # --- Labels et Style ---
    ax.set_xlabel(r"Sample Complexity $\alpha = n/d^2$", fontsize=11)
    ax.set_ylabel(ylabel, fontsize=11)
    
    ax.grid(True, linestyle='--', alpha=0.4)

    # --- STYLE BOÎTE ---
    ax.set_axisbelow(True)
    ax.tick_params(direction='in', top=True, right=True, which='both')
    
    for spine in ax.spines.values():
        spine.set_linewidth(1.0)

    # Légende
    ax.legend(frameon=True, fontsize=9, edgecolor='black', framealpha=1.0, loc=loc_legend)
    
    plt.tight_layout()
    
    # Sauvegarde
    # Défini plot_path si ce n'est pas fait ailleurs, sinon utilise "../plots/" par défaut
    output_dir = plot_path if 'plot_path' in locals() else "../plots/"
    if not os.path.exists(output_dir): os.makedirs(output_dir)
    
    save_full = os.path.join(output_dir, filename)
    plt.savefig(save_full, dpi=300, bbox_inches='tight')
    print(f"✅ Saved plot: {save_full}")
    plt.show()

# --- 4. Exécution ---

# On vérifie que les subsets contiennent des données
if not subset_S.empty:
    
    # Suffixe optionnel pour le nom du fichier
    run_suffix = f"_{run_id_S}" if 'run_id_S' in locals() else ""

    # -------------------- LABEL ERROR --------------------
    plot_compare_vs_alpha(
        subset_S, subset_S_sym, subset_S_sym_141,
        y_col="label_err_mean",
        y_err_col="label_err_std",
        ylabel="Test Error",
        filename=f"label_error_vs_alpha_MLP{MLP_target}_comparison{run_suffix}.png",
        loc_legend="upper right" 
    )

    # -------------------- TEST ACCURACY --------------------
    plot_compare_vs_alpha(
        subset_S, subset_S_sym, subset_S_sym_141,
        y_col="acc_test_mean",
        y_err_col="acc_test_std",
        ylabel="Test Accuracy",
        filename=f"test_accuracy_vs_alpha_MLP{MLP_target}_comparison{run_suffix}.png",
        loc_legend="lower right"
    )

else:
    print(f"⚠️ Main subset (S) is empty for MLP_dim = {MLP_target}. Check your filtering.")
# Out:
# ⚠️ Missing DataFrames: ['df_S', 'df_S_sym', 'df_S_sym_141']
# ⚠️ Main subset (S) is empty for MLP_dim = 100. Check your filtering.
